# %% [markdown]
# # EASY study heatmap generation

# %%
# imports, etc.
import ipywidgets as widgets
from IPython.display import display

# %%
# controls
slider = widgets.IntSlider()
display(slider)

# %%
slider.value

# %%
display(slider)

# %%
slider.close()

# %%
a = widgets.IntSlider(description='a')
b = widgets.IntSlider(description='b')
c = widgets.IntSlider(description='c')
def f(a, b, c):
    print('{}*{}*{}={}'.format(a, b, c, a*b*c))

out = widgets.interactive_output(f, {'a': a, 'b': b, 'c': c})

widgets.HBox([widgets.VBox([a, b, c]), out])

# %%
import getpass
import json
import re
import requests
#print(getpass.__version__)
print(json.__version__)
print(re.__version__)
print(requests.__version__)
# Out:
# 2.0.9
# 2.2.1
# 2.21.0

# %%
print(dir(widgets))

# %%
a = dict()
if not a:
    a['value'] = 1
print(a)

# %%
username = 'weberj3@mskcc.org'
password = None # do NOT enter here, will be requested via getpass!

# %%
from importlib import reload
import ISICApi
reload(ISICApi);

# %%
api = ISICApi.ISICApi(None, username, password)
st = api.getStudy('ISIC Annotation Study - All Features')
# Out:
# Password for user "weberj3@mskcc.org":········

# %%
st
# Out:
# {'_id': '5a32cde91165975cf58a469c',
#  '_modelType': 'study',
#  'created': '2017-12-14T19:15:53.895000+00:00',
#  'creator': {'_id': '55d4cde89fc3c1490e995086',
#   'firstName': 'Aadi',
#   'lastName': 'K',
#   'login': 'aadikalloo',
#   'name': 'User VDSM'},
#  'description': '',
#  'features': [{'id': 'Lines : Angulated lines / Polygons / Zig-zag pattern'},
#   {'id': 'Nail lesions : Blood spots'},
#   {'id': 'Structureless : Blotch irregular'},
#   {'id': 'Structureless : Blotch regular'},
#   {'id': 'Globules / Clods : Blue-gray ovoid nests'},
#   {'id': 'Structureless : Blue-whitish veil'},
#   {'id': 'Lines : Branched streaks'},
#   {'id': 'Structureless : Central white patch'},
#   {'id': 'Circles & Semicircles : Circle within a circle'},
#   {'id': 'Circles & Semicircles : Brown'},
#   {'id': 'Circles & Semicircles : NOS'},
#   {'id': 'Circles & Semicircles : White'},
#   {'id': 'Globules / Clods : Comedo-like openings'},
#   {'id': 'Globules / Clods : Concentric'},
# ...

# %%
print('ISIC_{0:07d}'.format(0))

# %%
print(ISICApi.isMongoObjectId('0123456789abcdef12345678'))
# Out:
# True

# %%
import re
mongoObjectIdPattern = re.compile(r"^[0-9a-f]{24}$")
def isMongoObjectId(testId:str = "") -> bool:
    return (len(testId) != 24 or (not re.match(mongoObjectIdPattern, testId)))

print(re.match(mongoObjectIdPattern, 'test'))
# Out:
# None
